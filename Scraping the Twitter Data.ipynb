# %% [markdown]
# # SNScrape

# %% [markdown]
# Using the SNScrape for scrapping the hashtags in twitter for further analysis of data.

# %%
import pandas as pd
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Pulling Tweet

# %%
scraper = sntwitter.TwitterSearchScraper("#datascience")
for tweet in scraper.get_items():
    break

# %%
tweet
# Out:
# Tweet(url='https://twitter.com/machinelearnflx/status/1620922103854759938', date=datetime.datetime(2023, 2, 1, 23, 8, 39, tzinfo=datetime.timezone.utc), rawContent='6 data science projects to boost your data science portfolio https://t.co/7whhBAH3GN  #DataScience', renderedContent='6 data science projects to boost your data science portfolio datasciencedojo.com/blog/data-scie…  #DataScience', id=1620922103854759938, user=User(username='machinelearnflx', id=4820804277, displayname='Machine Learning', rawDescription='Everything about #MachineLearning, #DeepLearning  #AI  #Bigdata  #Analytics #DataMining, #DataScience #Courses #Learning #Artificialintelligence', renderedDescription='Everything about #MachineLearning, #DeepLearning  #AI  #Bigdata  #Analytics #DataMining, #DataScience #Courses #Learning #Artificialintelligence', descriptionLinks=None, verified=False, created=datetime.datetime(2016, 1, 17, 11, 55, 58, tzinfo=datetime.timezone.utc), followersCount=154118, friendsCount=35831, statusesCount=497226, favouritesCount=271, listedCount=2812, mediaCount=19, location='', protected=False, link=TextLink(text='machinelearningflx.substack.com', url='https://machinelearningflx.substack.com/', tcourl='https://t.co/maTGNIcoWj', indices=(0, 23)), profileImageUrl='https://pbs.twimg.com/profile_images/688735459892195329/v8sHaWSG_normal.jpg', profileBannerUrl='https://pbs.twimg.com/profile_banners/4820804277/1504968657', label=None), replyCount=0, retweetCount=0, likeCount=0, quoteCount=0, conversationId=1620922103854759938, lang='en', source='<a href="https://twitter.com/pythonbot_" rel="nofollow">Postmatico</a>', sourceUrl='https://twitter.com/pythonbot_', sourceLabel='Postmatico', links=[TextLink(text='datasciencedojo.com/blog/data-scie…', url='https://datasciencedojo.com/blog/data-science-projects-to-build-portfolio/', tcourl='https://t.co/7whhBAH3GN', indices=(61, 84))], media=None, retweetedTweet=None, quotedTweet=None, inReplyToTweetId=None, inReplyToUser=None, mentionedUsers=None, coordinates=None, place=None, hashtags=['DataScience'], cashtags=None, card=SummaryCard(title='6 data science projects to boost your data science portfolio | Data Science Dojo', url='https://datasciencedojo.com/blog/data-science-projects-to-build-portfolio/', description='In this blog, we will discuss the latest 6 projects that can escalate your data science career and boost your data science portfolio in a competitive era.\xa0', thumbnailUrl='https://pbs.twimg.com/card_img/1619093073765490688/DSEk5tB5?format=png&name=orig', siteUser=User(username='DataScienceDojo', id=1318985240, displayname='Data Science Dojo', rawDescription='We make learning data science easy and fun! Join the 10,000+ professionals who started their successful Data Science careers with us. \n#DSDojo', renderedDescription='We make learning data science easy and fun! Join the 10,000+ professionals who started their successful Data Science careers with us. \n#DSDojo', descriptionLinks=None, verified=False, created=datetime.datetime(2013, 3, 31, 19, 25, 57, tzinfo=datetime.timezone.utc), followersCount=129196, friendsCount=977, statusesCount=42862, favouritesCount=5679, listedCount=2043, mediaCount=7955, location='Seattle, WA', protected=False, link=TextLink(text='datasciencedojo.com', url='https://datasciencedojo.com/', tcourl='https://t.co/xSbtUkHq34', indices=(0, 23)), profileImageUrl='https://pbs.twimg.com/profile_images/1609916008197668865/dq_eOEOk_normal.jpg', profileBannerUrl='https://pbs.twimg.com/profile_banners/1318985240/1667935586', label=None), creatorUser=User(username='DataScienceDojo', id=1318985240, displayname='Data Science Dojo', rawDescription='We make learning data science easy and fun! Join the 10,000+ professionals who started their successful Data Science careers with us. \n#DSDojo', renderedDescription='We make learning data science easy and fun! Join the 10,000+ professionals who started their successful Data Science careers with us. \n#DSDojo', descriptionLin ...

# %% [markdown]
# # Extract Tweet Data

# %%
scraper = sntwitter.TwitterSearchScraper("#Python")
tweets = []

for i, tweet in enumerate(scraper.get_items()):

    data = [
        tweet.date,
        tweet.id,
        tweet.content,
        tweet.user.username,
        tweet.likeCount,
        tweet.retweetCount,
    ]
    tweets.append(data)
    if i>50:
        break

# %%
tweets
#len(tweets)
# Out:
# [[datetime.datetime(2023, 2, 1, 23, 10, 7, tzinfo=datetime.timezone.utc),
#   1620922473658343424,
#   '公式ドキュメントに英語で説明があるにもかかわらず、それを日本語にして動画にしただけの講義が数万円で売られており、高評価を得ているのが現状です。英語読めるなら、公式ドキュメントで十分です。\n\n#Python \n#プログラミング',
#   'mhPZPibVjOUsZaZ',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 10, 1, tzinfo=datetime.timezone.utc),
#   1620922447162707970,
#   '👋 Vectorized is hiring Site Reliability Engineer \n\n💰 USD 150k-210k \n🛖 #remote #wfh \n💪 #SRE #python #go #golang #react #reactjs \n\n#tech #softwareengineer #jobs \nhttps://t.co/xyMHvBT9XF',
#   'echojobs_io',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 7, 45, tzinfo=datetime.timezone.utc),
#   1620921876334755841,
#   "The https://t.co/UgCx9vfmdb service for online notebooks is so good!! It makes it so easy to create links to  jupyter notebook that learners can play with interactively, e.g., here is a #Python tutorial I'm working on: https://t.co/X0yI5v05Hr Hands on learning for the win!",
#   'mcgillweb',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 7, 35, tzinfo=datetime.timezone.utc),
#   1620921834253213698,
#   '[定期]\nこんにちは、私の名前はGPBiPです\nGPBiPとは、とある #Discord のボットです\nミュージック機能などもありますが、目標は\n「痒い所に手が届く」ようにすること\n\n公式Discordサーバはこちら!\nhttps://t.co/BCzyiaOMsp\n\n導入はこちら!\nhttps://t.co/vbt81BvMAW\n\n#bot #Python #GPBiP',
#   'discord_GPBiP',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 7, 19, tzinfo=datetime.timezone.utc),
#   1620921769702969345,
#   'Test your CPU: Convert √(62) inches to centimeters. The result should be exactly 20 cm. If not, your CPU is faulty.#100Daysofcode #javascript #programming #dev #linux #java #programming #CodeNewbie #python #reactjs #bugbounty #DataScience #infosec #gamedev #BigData @programm… https://t.co/lFVAAdjLg3',
#   'programmerjoke9',
#   1,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 7, 15, tzinfo=datetime.timezone.utc),
#   1620921751302721536,
#   'webアプリを公開するために奮闘継続中...Nginxが起動しない…うーん🤔\n#webアプリ #webデザイン #web製作 #python  #udemy\u3000#conoha #ConoHa #コノハ',
#   'watasi_freelife',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 7, 6, tzinfo=datetime.timezone.utc),
#   1620921714753343488,
#   'Phases of #WebsiteDevelopment process!\n\nBy @NegliaDesign\n \n#WebDevelopment #WebDev #FrontEnd #BackEnd #FullStack #HTML #CSS #Python #JavaScript #Coding #Programming #WebDesign #WebDeveloper #Technology #Innovation #Serverless #IoT https://t.co/Tf3y7REabb',
#   'pratititech',
#   1,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 5, 49, tzinfo=datetime.timezone.utc),
#   1620921390827458560,
#   '#うひーメモ\n投稿時間:2023-02-02 08:05:48\nPython のエラー出力\nhttps://t.co/7kyWPQDiKY\n#python',
#   'uhiiman',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 5, 10, tzinfo=datetime.timezone.utc),
#   1620921225194229761,
#   '#Serverless computing will have a significant impact beyond cost savings for enterprises! \n\nDiscover more about it from this article: https://t.co/vk7cemnofr.\n\nVia  @ET_CIO\n\n#JavaScript #Cloud #Python #AWS #IoT #DataScience #DevOps #DigitalTransformation #Innovation #Technology https://t.co/gudhi2w0kV',
#   'forgeaheadio',
#   1,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 5, 9, tzinfo=datetime.timezone.utc),
#   1620921223814455296,
#   'Procurando dados sobre @GameOfThrones ?\n\nhttps://t.co/Idyi9kwCfz \n\naqui vc encontra os dados utilizados neste artigo: “Death is certain, the time is not”: mortality and survival in Game of Thrones. Injury Epidemiology 2018;5:44\n\nhttps://t.co/MxjSqc8SkA\n\n@marcelotournier #Python',
#   'DalsonFigueired',
#   4,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 4, 8, tzinfo=datetime.timezone.utc),
#   1620920968888848386,
#   'How to use measures to calculate profit margin in Power BI: These two measures make quick work of returning profit and calculating profit margin in your Power BI projects. The post How to use measures to calculate profit… https://t.co/48g7q7XwSh #opensource #programming #python',
#   'embedded_house',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 4, 6, tzinfo=datetime.timezone.utc),
#   1620920960881930240,
#   'How to create a project board in Taskade: Taskade makes it very easy to manage a list of tasks for small and mid-sized projects. Find out how to add a kanban-like board to your Workspace to make things even easier. The… https://t.co/tDueNXRpI1 #opensource #programming #python',
#   'embedded_house',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 3, 8, tzinfo=datetime.timezone.utc),
#   1620920716391780352,
#   'とにかく継続しよう\n＃Python\n【pytorchでニューラルネットワーク#5】単回帰分析（pytorch） https://t.co/dqseK9zx4N @YouTubeより',
#   'takuji1_nomura',
#   2,
#   1],
#  [datetime.datetime(2023, 2, 1, 23, 2, 8, tzinfo=datetime.timezone.utc),
#   1620920462153760768,
#   "🚨 IT'S YOUR LAST CHANCE 🚨 to jump on 💸 early-bird pricing 💸 for #PWC2023! 🐍 After 11:59 p.m. tonight, 25%-off pricing ends Get 'em while you can! #Python #Django #AI #ML #DevOps\n\nTickets: https://t.co/OB4PS30tgb \nSpeakers: https://t.co/H3FzprjNfl https://t.co/OpTLTrKJs9",
#   'pythonwebconf',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 23, 0, 50, tzinfo=datetime.timezone.utc),
#   1620920137736937473,
#   'Chill out with us at Radio Future:  \n\nRadio Station - https://t.co/thIoP3sJE2\n\nStream Url - https://t.co/nHVUQbDvua\n\n #Letsconnect #NFT #Web3 #Tech #Music #Radio #Song #AI #ML #Python #100daysofcode #React #Coding #DataScience https://t.co/23qdd1NPmL',
#   'Radio_Future_',
#   3,
#   2],
#  [datetime.datetime(2023, 2, 1, 23, 0, 35, tzinfo=datetime.timezone.utc),
#   1620920071940882434,
#   "Let's check on @InterSystemsDev how to easily create and read Microsoft Word documents using #InterSystemsIRIS with the leverage power of embedded #Python! https://t.co/K5TLju72ZO https://t.co/fZVpLyNsYE",
#   'rcemper1',
#   0,
#   1],
#  [datetime.datetime(2023, 2, 1, 23, 0, 23, tzinfo=datetime.timezone.utc),
#   1620920023630979073,
#   'Need some help with Python Scripts? The Library in Cyber Social Hub offers some great resources to assist you with your investigations. Free for all members, check it out today! https://t.co/wRkqrD3f1b\n\n#python #pythonscripts #dfir #investigation https://t.co/dGbUCNMrQg',
#   'CyberSocialHub',
#   0,
#   1],
#  [datetime.datetime(2023, 2, 1, 23, 0, 18, tzinfo=datetime.timezone.utc),
#   1620920001359405056,
#   '2,000 free sign ups available for the "Automate the Boring Stuff with Python" online course. (Feb 2023) [Resource] #Python https://t.co/jUuulW6G54',
#   'data_cyborg',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 0, 14, tzinfo=datetime.timezone.utc),
#   1620919985320370176,
#   'I’m developing a programming game where you use Python to automate all kinds of machines, robots, drones and more and solve exciting bite-sized coding ch... [Resource] #Python https://t.co/hN7cyu2I5L',
#   'data_cyborg',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 23, 0, 11, tzinfo=datetime.timezone.utc),
#   1620919974276788224,
#   'ラズベリーパイより、2月2日8時0分の空模様と気温 -6.188℃ #raspberrypi #python #fswebcam #photo #北海道 #オホーツク #イマソラ https://t.co/VG1JWLjJ4i',
#   'shima_farm',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 23, 0, 11, tzinfo=datetime.timezone.utc),
#   1620919973328584704,
#   'George has done a data science project involving NumPy. Well done, George! 🤩🙌🏼\n\n#m2mtechbytes #coding #design #designthinking #100DaysOfCode #GirlsWhoCode #tech #coding #compsci #3DModelling  #STEM #programming #python  #Tech #javascript #bigdata #Linux #NumPy #datascience https://t.co/UGvMHACLoq',
#   'techbytesorg',
#   3,
#   4],
#  [datetime.datetime(2023, 2, 1, 23, 0, 9, tzinfo=datetime.timezone.utc),
#   1620919964374007808,
#   '2023/02/02 08:00のトレンド1位は #プリキュア !! #python, #Mecab, #wordcloud https://t.co/XLYl7gvCSG',
#   'PythonBot0728',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 23, 0, 5, tzinfo=datetime.timezone.utc),
#   1620919946250174464,
#   'Top 5 category on twitch right now : \nJust Chatting 🔄 \nGrand Theft Auto V 🔄 \nLeague of Legends 🔄 \nVALORANT 🔄 \nCounter-Strike: Global Offensive 🔄 \n🐥🚀👍 \n #twitch #gaming #twitchstreamer #livestream #python #bot',
#   'TopFiveTwitch',
#   3,
#   2],
#  [datetime.datetime(2023, 2, 1, 23, 0, 3, tzinfo=datetime.timezone.utc),
#   1620919939090481155,
#   '👋 Roblox is hiring Principal Site Reliability Engineer \n\n💰 USD 312k-377k \n🌇 US, San Mateo, CA \n💪 #SRE #python #go #golang \n\n#tech #softwareengineer #jobs \nhttps://t.co/B960Ga06cW',
#   'echojobs_io',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 59, 26, tzinfo=datetime.timezone.utc),
#   1620919785671331847,
#   'How to Use Python to Scrape the Top 5 Results From Google or YouTube for Any Keyword\n#Python #Google #YouTube #WebScraping\n\nhttps://t.co/ghdheggq7d https://t.co/qKA2MlhBh5',
#   'mrcollinsllb',
#   2,
#   2],
#  [datetime.datetime(2023, 2, 1, 22, 56, 39, tzinfo=datetime.timezone.utc),
#   1620919083230461952,
#   'Dual Lens Camera Module\n#Robotics #AI #IoT #Video #Imaging #Tensorflow #Matlab #Ubantu #Python #NVIDIA #Drone #Agritech #Biometrics #DepthSensing #3D #Facerecognition #Robot #MachineVision #MachineLearning #DeepLearning #OpenCV #Linux #VR #ComputerVision #Algorithm #Embedded https://t.co/8R6tWrSChb',
#   'CameraModuleAI',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 56, 26, tzinfo=datetime.timezone.utc),
#   1620919030751334400,
#   'Dual Lens Camera Module\n#Robotics #AI #IoT #Video #Imaging #Tensorflow #Matlab #Ubantu #Python #NVIDIA #Drone #Agritech #Biometrics #DepthSensing #3D #Facerecognition #Robot #MachineVision #MachineLearning #DeepLearning #OpenCV #Linux #VR #ComputerVision #Algorithm #Embedded https://t.co/2yW78uzJ6v',
#   'CameraModuleAI',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 56, 17, tzinfo=datetime.timezone.utc),
#   1620918991027073024,
#   'Dual Lens Camera Module\n#Robotics #AI #IoT #Video #Imaging #Tensorflow #Matlab #Ubantu #Python #NVIDIA #Drone #Agritech #Biometrics #DepthSensing #3D #Facerecognition #Robot #MachineVision #MachineLearning #DeepLearning #OpenCV #Linux #VR #ComputerVision #Algorithm #Embedded https://t.co/Dyzt5jDnWg',
#   'CameraModuleAI',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 56, 11, tzinfo=datetime.timezone.utc),
#   1620918968566386690,
#   'Are junior developers actually useless?\n\n#Python #javascript #programming #programminghumor #programmingmemes https://t.co/yL4It0gDGE',
#   'inmicahineworks',
#   3,
#   2],
#  [datetime.datetime(2023, 2, 1, 22, 56, 10, tzinfo=datetime.timezone.utc),
#   1620918961083645955,
#   'Junior devs at their finest (tic tac toe winner checks)\n\n#Python #javascript #programming #programminghumor #programmingmemes https://t.co/cflBfJmbOk',
#   'inmicahineworks',
#   3,
#   2],
#  [datetime.datetime(2023, 2, 1, 22, 56, 6, tzinfo=datetime.timezone.utc),
#   1620918947427282944,
#   'Dual Lens Camera Module\n#Robotics #AI #IoT #Video #Imaging #Tensorflow #Matlab #Ubantu #Python #NVIDIA #Drone #Agritech #Biometrics #DepthSensing #3D #Facerecognition #Robot #MachineVision #MachineLearning #DeepLearning #OpenCV #Linux #VR #ComputerVision #Algorithm #Embedded https://t.co/ZuKnaZzXqo',
#   'CameraModuleAI',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 55, 56, tzinfo=datetime.timezone.utc),
#   1620918904653766657,
#   'Dual Lens Camera Module\n#Robotics #AI #IoT #Video #Imaging #Tensorflow #Matlab #Ubantu #Python #NVIDIA #Drone #Agritech #Biometrics #DepthSensing #3D #Facerecognition #Robot #MachineVision #MachineLearning #DeepLearning #OpenCV #Linux #VR #ComputerVision #Algorithm #Embedded https://t.co/RrBpAbwQlS',
#   'CameraModuleAI',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 55, 34, tzinfo=datetime.timezone.utc),
#   1620918811598917635,
#   'Dual Lens Camera Module\n#Robotics #AI #IoT #Video #Imaging #Tensorflow #Matlab #Ubantu #Python #NVIDIA #Drone #Agritech #Biometrics #DepthSensing #3D #Facerecognition #Robot #MachineVision #MachineLearning #DeepLearning #OpenCV #Linux #VR #ComputerVision #Algorithm #Embedded https://t.co/V9zeVCuFwj',
#   'CameraModuleAI',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 54, 57, tzinfo=datetime.timezone.utc),
#   1620918654379466754,
#   'Day 14 #100daysofcodechallenge #python https://t.co/QtPJQuxvwn https://t.co/HJlIWJWHDj',
#   'EniAkanbi',
#   0,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 54, tzinfo=datetime.timezone.utc),
#   1620918416533245952,
#   'A lot of Staff #100DaysOfCode with #Python &lt;Day 08&gt;, &lt;Day 09&gt; and &lt;Day 10&gt; 😄',
#   'MarcinChruszcz',
#   2,
#   2],
#  [datetime.datetime(2023, 2, 1, 22, 51, 47, tzinfo=datetime.timezone.utc),
#   1620917858732744705,
#   'Backend or frontend developers in Lisbon with experience in Vue, React, Go or Python, if you’re looking for a new   position where you’d get to work on an AI and machine learning translation service then hit me up\n#golang #Python #reactjs #VueJS #softwaredevelopment #lisbon #tech',
#   'nimblewit_',
#   1,
#   2],
#  [datetime.datetime(2023, 2, 1, 22, 50, 19, tzinfo=datetime.timezone.utc),
#   1620917489592078336,
#   'Speed up your time to market with #SQLAlchemy - just like @Lua_Labs 💥 Streamline database management &amp; say goodbye to raw SQL statements with this popular open-source SQL toolkit &amp; ORM library for #Python 💻 Experience a flexible &amp; high-level approach to database interaction 🔥',
#   'Lua_Labs',
#   3,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 50, 2, tzinfo=datetime.timezone.utc),
#   1620917420306087939,
#   '🐬 GoDaddy is hiring Principal Software Engineer \n\n🌇 Colombia \n💪 #javascript #python #kubernetes #docker #terraform \n\n#tech #softwareengineer #jobs \nhttps://t.co/xvgDB4uZew',
#   'echojobs_io',
#   1,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 48, 47, tzinfo=datetime.timezone.utc),
#   1620917102818516993,
#   'Want even more information?\n\nJump on over to https://t.co/NXMxqMUU5W and explore the various developer tools and tutorials!\n\n#Rust #Scala #JavaScript #Python https://t.co/3TSBnhCh39',
#   'Ergo_Platform',
#   1,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 47, 28, tzinfo=datetime.timezone.utc),
#   1620916773603233794,
#   'No. MMDCCCXXVI\n#colorway #shapeways #drawing #processing #python #creativecoding #generativeart #jimbo https://t.co/PWBoznhV9U',
#   'shapewaze',
#   1,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 47, 24, tzinfo=datetime.timezone.utc),
#   1620916754284220417,
#   'No. MMMIV\n#grayway #shapeways #drawing #processing #python #creativecoding #generativeart #jimbo https://t.co/zyzlR6XhAC',
#   'shapewaze',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 47, 16, tzinfo=datetime.timezone.utc),
#   1620916723107987456,
#   'No. MMMIII\n#grayway #shapeways #drawing #processing #python #creativecoding #generativeart #jimbo https://t.co/tmBmDJMk4M',
#   'shapewaze',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 46, 42, tzinfo=datetime.timezone.utc),
#   1620916578182389760,
#   '#codinglife #DataScience #DataAnalytics #SQL #Python #R https://t.co/v5oCrvy7SH',
#   'kaeptnkrunch',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 45, 54, tzinfo=datetime.timezone.utc),
#   1620916377711247361,
#   'Text me now for any hacking or bypass Active 24/7 \nUpgrade and Account Recoveries.\n#cybercrime\n#programmer #malware #cyberattack\n#informationsecurity #python #coding\n#hackerindonesia #tech #cybersecurityawareness',
#   'dolly_meta',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 44, 33, tzinfo=datetime.timezone.utc),
#   1620916040460042240,
#   'プログラミングスクールの闇について書きました\n\n検討している方はご参考にください\n\nスクールはあくまでも学習の手助けをしてくれるに過ぎません\n\n卒業後も継続的な努力は必要です\n#プログラミング #プログラミングスクール #駆け出しエンジニアと繋がりたい #Python\nhttps://t.co/YmDSsyZedh',
#   'investortat',
#   3,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 44, 26, tzinfo=datetime.timezone.utc),
#   1620916009300365313,
#   'We are reliable to offer you A grade in your;\n✓nursing\n✓essays\n✓chemistry\n✓finance\n✓physics\n✓biology\n✓physics\n✓chemistry\n✓algebra\n✓calculus\n✓essay pay\n✓Assignment due\n\n#100DaysOfCode\n#WomenWhoCode\n#javascript\n#Python\n#Serverless\n#Asu #IoT\nHit our Bio for More info:) https://t.co/4LxFRYd9Sf',
#   'AcademicsAplus',
#   1,
#   2],
#  [datetime.datetime(2023, 2, 1, 22, 44, 14, tzinfo=datetime.timezone.utc),
#   1620915959476133888,
#   'Fluent Python: Clear, Concise, and Effective Programming https://t.co/YX0OWk069G  #Python #ad',
#   'pythonbot_',
#   1,
#   1],
#  [datetime.datetime(2023, 2, 1, 22, 42, 49, tzinfo=datetime.timezone.utc),
#   1620915600737419264,
#   'We are reliable to offer you A grade in your;\n✓nursing\n✓essays\n✓chemistry\n✓finance\n✓physics\n✓biology\n✓physics\n✓chemistry\n✓algebra\n✓calculus\n✓essay pay\n✓Assignment due\n\n#100DaysOfCode\n#WomenWhoCode\n#javascript\n#Python\n#Serverless\n#Asu #IoT\nHit our Bio for More info\nDm',
#   '_topwritings',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 42, 15, tzinfo=datetime.timezone.utc),
#   1620915462187147264,
#   'https://t.co/Ybm7JxlzJs #Python #ChatGPT',
#   'davidegazze',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 40, 6, tzinfo=datetime.timezone.utc),
#   1620914918097829888,
#   'streamlitで秒速アプリ作成\n\n$python -m venv app\n$source app/bin/activate\n$pip install streamlit\n$cd app\n$touch https://t.co/oGE8rjXkQo\n$streamlit run https://t.co/oGE8rjXkQo\n\nmacで仮想環境でWebアプリの型が完成します。あとは公式docsを参考に作っていくだけ\n\n#Python \n#プログラミング',
#   'mhPZPibVjOUsZaZ',
#   2,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 40, tzinfo=datetime.timezone.utc),
#   1620914895830061057,
#   '🌅 DoorDash is hiring Software Engineer \n\n💰 USD 144k-230k \n🛖 #remote #wfh \n💪 #python #aws #machinelearning #java #spark \n\n#tech #softwareengineer #jobs \nhttps://t.co/q1ABZaynrO',
#   'echojobs_io',
#   0,
#   0],
#  [datetime.datetime(2023, 2, 1, 22, 39, 44, tzinfo=datetime.timezone.utc),
#   1620914824925282306,
#   'Learn 🐍#Python Quickly - Interactive Tutorial\n⚡️Conditions - Exercise⚡️\n\n👉💻https://t.co/3E7aeJizwX\n\n5hr Free Python Course: https://t.co/VOvpcK8Vqk\n#100DaysOfCode #CodeNewbies #Coding #DataScience #MachineLearning #Analytics #AI #Tech #BigData https://t.co/nb81TKa9Yt',
#   'OlofPaulson',
#   2,
#   0]]

# %%
tweet_df = pd.DataFrame(
    tweets, columns=["date", "id", "content", "username", "like_count", "retweet_count"]
)

# %%
tweet_df.to_csv("python-tweets.csv", index = False)

# %% [markdown]
# # Adding a Progress Bar

# %%
scraper = sntwitter.TwitterSearchScraper("#Python")
tweets = []

n_tweets = 1_000

for i, tweet in tqdm(enumerate(scraper.get_items()), total = n_tweets):

    data = [
        tweet.date,
        tweet.id,
        tweet.content,
        tweet.user.username,
        tweet.likeCount,
        tweet.retweetCount,
    ]
    
    tweets.append(data)
    if i>n_tweets:
        break
        
tweet_df = pd.DataFrame(
    tweets, columns=["date", "id", "content", "username", "like_count", "retweet_count"]
)
tweet_df.to_csv("python-tweets.csv", index = False)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
